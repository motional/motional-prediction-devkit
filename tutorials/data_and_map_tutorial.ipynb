# %%
import pandas as pd
trajectories = pd.read_parquet("sample_data.parquet")

# %%
trajectories
# Out:
#               timestamp       track_token              x             y  \
# 277    1626711601051115  041da55d0c985ccf  664498.046272  3.995878e+06
# 264    1626711601051115  0d30b6f599e85c94  664499.216194  3.995878e+06
# 224    1626711601051115  0f72f4b0cf5657ae  664500.782169  3.995850e+06
# 222    1626711601051115  10c02af72a205595  664501.063391  3.995845e+06
# 260    1626711601051115  1314873307325b47  664473.495306  3.995853e+06
# ...                 ...               ...            ...           ...
# 19088  1626711611000457  fa57809fb7c050d5  664499.436895  3.995848e+06
# 19015  1626711611000457  fa86c40aa9b65f8f  664494.826318  3.995848e+06
# 19026  1626711611000457  fc281aaae3155ff2  664480.615965  3.995874e+06
# 19005  1626711611000457  fd09c13a594152ec  664500.616401  3.995854e+06
# 19013  1626711611000457  fe0499e6a3be5bbd  664511.879834  3.995857e+06
#
#                 z        vx        vy        vz     length     width  \
# 277    632.881002  0.000000  0.000000  0.000000   0.544623  0.556809
# 264    632.819183 -0.000813 -0.000240  0.001048   0.461883  0.470060
# 224    632.159965  0.000376  0.000082 -0.000018   0.405174  0.408886
# 222    632.203007  0.000227  0.000073  0.000014   0.470853  0.476469
# 260    632.092741 -0.000907 -0.000209  0.000018   0.411332  0.416784
# ...           ...       ...       ...       ...        ...       ...
# 19088  632.977025 -0.000160  0.000329 -0.000325   0.163735  1.402443
# 19015  632.154310 -0.001193 -0.000107 -0.000026   1.248076  1.525141
# 19026  635.470253  0.000000  0.000000  0.000000  12.018017  5.408929
# 19005  631.852703 -0.000069  0.000099 -0.000014   0.462828  0.477562
# 19013  631.528137  0.000283  0.000438  0.000031   0.359684  0.356442
#
#          height   category_name       city
# 277    1.416437    traffic_cone  las_vegas
# 264    1.412394    traffic_cone  las_vegas
# 224    1.333974    traffic_cone  las_vegas
# 222    1.417299    traffic_cone  las_vegas
# 260    1.238588    traffic_cone  las_vegas
# ...         ...             ...        ...
# 19088  0.958324      czone_sign  las_vegas
# 19015  1.731559         barrier  las_vegas
# 19026  9.721447         vehicle  las_vegas
# 19005  1.396478    traffic_cone  las_vegas
# 19013  1.200986  generic_object  las_vegas
#
# [19104 rows x 13 columns]

# %%
# get all vehicles
vehicles = trajectories[trajectories["category_name"] == "vehicle"]
vehicles
# Out:
#               timestamp       track_token              x             y  \
# 216    1626711601051115  2a931b98359f5a56  664483.396907  3.995807e+06
# 223    1626711601051115  3d7f0ad295f85425  664476.212350  3.995841e+06
# 200    1626711601051115  489ec8e811b85bd5  664508.046528  3.995803e+06
# 202    1626711601051115  4b64a065c23a5b35  664507.548933  3.995787e+06
# 201    1626711601051115  64f68b027e86511a  664507.833085  3.995796e+06
# ...                 ...               ...            ...           ...
# 19027  1626711611000457  da2bc8721b245ebf  664479.071627  3.995846e+06
# 18989  1626711611000457  de0caed92a1256e9  664490.790997  3.995781e+06
# 18998  1626711611000457  ec121722061554da  664482.971366  3.995822e+06
# 18991  1626711611000457  ecc29f166fb95b83  664489.398094  3.995789e+06
# 19026  1626711611000457  fc281aaae3155ff2  664480.615965  3.995874e+06
#
#                 z        vx        vy       vz     length     width    height  \
# 216    632.392008  0.000000  0.000000  0.00000   4.549896  1.912419  1.958184
# 223    632.867869  0.000000  0.000000  0.00000   6.747249  2.551741  3.023172
# 200    631.725722  0.000000  0.000000  0.00000   4.506899  1.891657  1.581151
# 202    631.607012  0.000000  0.000000  0.00000   4.765264  1.988360  1.813796
# 201    631.711624  0.000000  0.000000  0.00000   4.659972  1.936712  1.636135
# ...           ...       ...       ...      ...        ...       ...       ...
# 19027  633.454148  0.254283 -1.875179 -0.00028  10.248010  3.857772  4.375308
# 18989  632.412155  0.000000  0.000000  0.00000   5.927864  2.336039  2.607989
# 18998  632.440457  0.000000  0.000000  0.00000   4.705783  1.925480  1.868047
# 18991  632.314802  0.000000  0.000000  0.00000   6.041584  2.211489  2.152917
# 19026  635.470253  0.000000  0.000000  0.00000  12.018017  5.408929  9.721447
#
#       category_name       city
# 216         vehicle  las_vegas
# 223         vehicle  las_vegas
# 200         vehicle  las_vegas
# 202         vehicle  las_vegas
# 201         vehicle  las_vegas
# ...             ...        ...
# 19027       vehicle  las_vegas
# 18989       vehicle  las_vegas
# 18998       vehicle  las_vegas
# 18991       vehicle  las_vegas
# 19026       vehicle  las_vegas
#
# [3084 rows x 13 columns]

# %%
# get the trajectory from a vehicle
vid = vehicles["track_token"].unique().tolist()[3]
trajectory = vehicles[vehicles["track_token"]==vid]
trajectory
# Out:
#               timestamp       track_token              x             y  \
# 202    1626711601051115  4b64a065c23a5b35  664507.548933  3.995787e+06
# 281    1626711601101130  4b64a065c23a5b35  664507.552923  3.995787e+06
# 359    1626711601151145  4b64a065c23a5b35  664507.541292  3.995787e+06
# 437    1626711601201161  4b64a065c23a5b35  664507.573177  3.995787e+06
# 516    1626711601251177  4b64a065c23a5b35  664507.564455  3.995787e+06
# ...                 ...               ...            ...           ...
# 18497  1626711610800627  4b64a065c23a5b35  664507.484896  3.995790e+06
# 18619  1626711610850583  4b64a065c23a5b35  664507.480975  3.995790e+06
# 18742  1626711610900539  4b64a065c23a5b35  664507.481160  3.995790e+06
# 18863  1626711610950498  4b64a065c23a5b35  664507.483506  3.995790e+06
# 18984  1626711611000457  4b64a065c23a5b35  664507.474044  3.995791e+06
#
#                 z        vx        vy        vz    length    width    height  \
# 202    631.607012  0.000000  0.000000  0.000000  4.765264  1.98836  1.813796
# 281    631.612767  0.000000  0.000000  0.000000  4.765264  1.98836  1.813796
# 359    631.614847  0.000000  0.000000  0.000000  4.765264  1.98836  1.813796
# 437    631.612028  0.000000  0.000000  0.000000  4.765264  1.98836  1.813796
# 516    631.613235  0.000000  0.000000  0.000000  4.765264  1.98836  1.813796
# ...           ...       ...       ...       ...       ...      ...       ...
# 18497  631.775898 -0.053291  2.424906 -0.014059  4.765264  1.98836  1.813796
# 18619  631.788981 -0.043406  2.478398 -0.016216  4.765264  1.98836  1.813796
# 18742  631.801543 -0.033672  2.550495 -0.016994  4.765264  1.98836  1.813796
# 18863  631.793434 -0.029385  2.582772 -0.014127  4.765264  1.98836  1.813796
# 18984  631.809127 -0.028502  2.624372 -0.015220  4.765264  1.98836  1.813796
#
#       category_name       city
# 202         vehicle  las_vegas
# 281         vehicle  las_vegas
# 359         vehicle  las_vegas
# 437         vehicle  las_vegas
# 516         vehicle  las_vegas
# ...             ...        ...
# 18497       vehicle  las_vegas
# 18619       vehicle  las_vegas
# 18742       vehicle  las_vegas
# 18863       vehicle  las_vegas
# 18984       vehicle  las_vegas
#
# [200 rows x 13 columns]

# %%
import sys
sys.path.append('../')

# configure your map root, change to your own path
MAP_ROOT = "/data/exp/jinghuan.shang/nuplan/v1.1/maps/"

# get map api for a city
from map.utils import get_all_maps_api, parquet_city_name_to_map_api_name
city = trajectory["city"].unique().tolist()[0]
city = parquet_city_name_to_map_api_name(city)
map_api = get_all_maps_api(MAP_ROOT, [city])[city]
map_api

# %%
# use this vehicle location as the center of queried map
from map.geometry.geometry import Point2D
vehicle_location = Point2D(trajectory.iloc[0]["x"], trajectory.iloc[0]["y"])

# configure a radius (m)
radius = 20

# use the api
from map.nuplan_map.vector_map_utils import get_neighbor_vector_map
vector_map = get_neighbor_vector_map(map_api, vehicle_location, 20)

# %%
lane_seg_coords, lane_seg_conns, lane_seg_groupings, lane_seg_lane_ids, lane_seg_roadblock_ids = vector_map
# lane_seg_coords: lane_segment coords in shape of [num_lane_segment, 2, 2].
# lane_seg_conns: lane_segment connections [start_idx, end_idx] in shape of [num_connection, 2].
# lane_seg_groupings: collection of lane_segment indices in each lane in shape of
#     [num_lane, num_lane_segment_in_lane].
# lane_seg_lane_ids: lane ids of segments at given index in coords in shape of [num_lane_segment 1].
# lane_seg_roadblock_ids: roadblock ids of segments at given index in coords in shape of [num_lane_segment 1].

# %%
# lane segments in within the queired range
# shape of [num_lane_segment, 2, 2]
len(lane_seg_coords), lane_seg_coords[0]
# Out:
# (863,
#  [[664501.3599773038, 3995782.2145186644],
#   [664501.3531707184, 3995782.464425988]])

# %%
# connections [start_idx, end_idx] between these lanes
len(lane_seg_conns), lane_seg_conns[:5]
# Out:
# (857, [(0, 1), (1, 2), (2, 3), (3, 4), (4, 5)])
